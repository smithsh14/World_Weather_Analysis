# %%
# Deliverable 1 Start

# %%
#Import the Dependecies for project.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
#Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-90.000, high=90.000, size=2000)
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
#Add latitudes and longitudes to a list.
coordinates = list(lats_lngs)

# %%
#Use citipy module to locate the nearest city.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 745

# %%
import requests
requests.__version__
# Out:
# '2.26.0'

# %%
#Import the requests library.
import requests

# %%
#Import the API Key
from config import weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
#Perform an API call with the OpenWeatherMap
url = "https://api.openweathermap.org/data/2.5/weather?units=Imerial&APPID=" + weather_api_key

# %%
#Retrieve information from the API call.
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count.
    record_count += 1

    # Run an API request for each of the cities.
    try:
        
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()

        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]

        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description,
                          "Date": city_date})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 1 | dikson
# Processing Record 4 of Set 1 | porto velho
# Processing Record 5 of Set 1 | cap-aux-meules
# Processing Record 6 of Set 1 | channel-port aux basques
# Processing Record 7 of Set 1 | itarema
# Processing Record 8 of Set 1 | kikwit
# Processing Record 9 of Set 1 | kayes
# Processing Record 10 of Set 1 | hithadhoo
# Processing Record 11 of Set 1 | vangaindrano
# Processing Record 12 of Set 1 | nuuk
# Processing Record 13 of Set 1 | longyearbyen
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | hermanus
# Processing Record 16 of Set 1 | qaanaaq
# Processing Record 17 of Set 1 | bambous virieux
# Processing Record 18 of Set 1 | adrar
# Processing Record 19 of Set 1 | upernavik
# Processing Record 20 of Set 1 | ilulissat
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | karlstad
# Processing Record 23 of Set 1 | georgetown
# Processing Record 24 of Set 1 | port alfred
# Processing Record 25 of Set 1 | souillac
# Processing Record 26 of Set 1 | ponta do sol
# Processing Record 27 of Set 1 | kyrylivka
# Processing Record 28 of Set 1 | bredasdorp
# Processing Record 29 of Set 1 | abay
# Processing Record 30 of Set 1 | jalu
# Processing Record 31 of Set 1 | kruisfontein
# Processing Record 32 of Set 1 | maniitsoq
# Processing Record 33 of Set 1 | mahebourg
# Processing Record 34 of Set 1 | chaman
# Processing Record 35 of Set 1 | izhma
# Processing Record 36 of Set 1 | bathsheba
# Processing Record 37 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 1 | glowno
# Processing Record 39 of Set 1 | nueva loja
# Processing Record 40 of Set 1 | saint-philippe
# Processing Record 41 of Set 1 | kazalinsk
# City not found. Skipping...
# Processing Record 42 of Set 1 | mitsamiouli
# Processing Record 43 of Set 1 | puerto del rosario
# Processing Record 44 of Set 1 | antofagasta
# Processing Record 45 of Set 1 | xique-xique
# Processing Record 46 of Set 1 | lemesos
# City not found. Skipping...
# Processing Record 47 of Set 1 | marsa matruh
# Processing Record 48 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 49 of Set 1 | saldanha
# Processing Record 50 of Set 1 | clyde river
# Processing Record 1 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 2 of Set 2 | mar del plata
# Processing Record 3 of Set 2 | knysna
# Processing Record 4 of Set 2 | saint-augustin
# Processing Record 5 of Set 2 | mehamn
# Processing Record 6 of Set 2 | santo tomas
# Processing Record 7 of Set 2 | unye
# City not found. Skipping...
# Processing Record 8 of Set 2 | mamallapuram
# Processing Record 9 of Set 2 | bengkulu
# Processing Record 10 of Set 2 | sotnikovskoye
# Processing Record 11 of Set 2 | arcachon
# Processing Record 12 of Set 2 | hvammstangi
# City not found. Skipping...
# Processing Record 13 of Set 2 | chakulia
# Processing Record 14 of Set 2 | kommunar
# Processing Record 15 of Set 2 | pinega
# Processing Record 16 of Set 2 | dehloran
# Processing Record 17 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 18 of Set 2 | codrington
# Processing Record 19 of Set 2 | cravo norte
# Processing Record 20 of Set 2 | saint-leu
# Processing Record 21 of Set 2 | inongo
# Processing Record 22 of Set 2 | ornes
# Processing Record 23 of Set 2 | saint-joseph
# Processing Record 24 of Set 2 | husavik
# Processing Record 25 of Set 2 | viligili
# City not found. Skipping...
# Processing Record 26 of Set 2 | klaksvik
# Processing Record 27 of Set 2 | skalistyy
# City not found. Skipping...
# Processing Record 28 of Set 2 | rypefjord
# Processing Record 29 of Set 2 | svetlogorsk
# Processing Record 30 of Set 2 | diu
# Processing Record 31 of Set 2 | touros
# Processing Record 32 of Set 2 | cape town
# Processing Record 33 of Set 2 | lagoa
# Processing Record 34 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 35 of Set 2 | macon
# Processing Record 36 of Set 2 | afmadu
# City not found. Skipping...
# Processing Record 37 of Set 2 | yar-sale
# Processing Record 38 of Set 2 | goundam
# Processing Record 39 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 40 of Set 2 | tasiilaq
# Processing Record 41 of Set 2 | luba
# Processing Record 42 of Set 2 | vaasa
# Processing Record 43 of Set 2 | gharb
# City not found. Skipping...
# Processing Record 44 of Set 2 | rocha
# Processing Record 45 of Set 2 | harper
# Processing Record 46 of Set 2 | east london
# Processing Record 47 of Set 2 | iqaluit
# Processing Record 48 of Set 2 | jamestown
# Processing Record 49 of Set 2 | victoria
# Processing Record 50 of Set 2 | opuwo
# Processing Record 1 of Set 3 | aksu
# Processing Record 2 of Set 3 | valkeala
# Processing Record 3 of Set 3 | cayenne
# Processing Record 4 of Set 3 | upata
# Processing Record 5 of Set 3 | cidreira
# Processing Record 6 of Set 3 | eyl
# Processing Record 7 of Set 3 | barranca
# Processing Record 8 of Set 3 | buqayq
# City not found. Skipping...
# Processing Record 9 of Set 3 | brae
# Processing Record 10 of Set 3 | chuy
# Processing Record 11 of Set 3 | sakakah
# Processing Record 12 of Set 3 | lebu
# Processing Record 13 of Set 3 | cervo
# Processing Record 14 of Set 3 | valparaiso
# Processing Record 15 of Set 3 | punta arenas
# Processing Record 16 of Set 3 | kashi
# Processing Record 17 of Set 3 | gornopravdinsk
# Processing Record 18 of Set 3 | laguna
# Processing Record 19 of Set 3 | iquitos
# Processing Record 20 of Set 3 | galgani
# City not found. Skipping...
# Processing Record 21 of Set 3 | contamana
# Processing Record 22 of Set 3 | muros
# Processing Record 23 of Set 3 | springs
# Processing Record 24 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 3 | arraial do cabo
# Processing Record 26 of Set 3 | strezhevoy
# Processing Record 27 of Set 3 | port elizabeth
# Processing Record 28 of Set 3 | formoso do araguaia
# City not found. Skipping...
# Processing Record 29 of Set 3 | amapa
# Processing Record 30 of Set 3 | la rioja
# Processing Record 31 of Set 3 | cradock
# Processing Record 32 of Set 3 | millerovo
# Processing Record 33 of Set 3 | port-gentil
# Processing Record 34 of Set 3 | sawakin
# Processing Record 35 of Set 3 | cuamba
# Processing Record 36 of Set 3 | filadelfia
# Processing Record 37 of Set 3 | kokstad
# Processing Record 38 of Set 3 | saint george
# Processing Record 39 of Set 3 | nauta
# Processing Record 40 of Set 3 | sur
# Processing Record 41 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 42 of Set 3 | chimbarongo
# Processing Record 43 of Set 3 | vyshkov
# Processing Record 44 of Set 3 | plettenberg bay
# Processing Record 45 of Set 3 | natal
# Processing Record 46 of Set 3 | conde
# Processing Record 47 of Set 3 | carutapera
# Processing Record 48 of Set 3 | semey
# Processing Record 49 of Set 3 | fougamou
# Processing Record 50 of Set 3 | doba
# Processing Record 1 of Set 4 | tela
# Processing Record 2 of Set 4 | nokha
# Processing Record 3 of Set 4 | piacabucu
# Processing Record 4 of Set 4 | kutum
# Processing Record 5 of Set 4 | vila velha
# Processing Record 6 of Set 4 | ji-parana
# City not found. Skipping...
# Processing Record 7 of Set 4 | aquiraz
# Processing Record 8 of Set 4 | gornyak
# Processing Record 9 of Set 4 | middelburg
# Processing Record 10 of Set 4 | nanortalik
# Processing Record 11 of Set 4 | pisco
# Processing Record 12 of Set 4 | giddarbaha
# Processing Record 13 of Set 4 | boden
# Processing Record 14 of Set 4 | tacoronte
# Processing Record 15 of Set 4 | azare
# Processing Record 16 of Set 4 | pangnirtung
# Processing Record 17 of Set 4 | manicore
# Processing Record 18 of Set 4 | tonneins
# Processing Record 19 of Set 4 | tarko-sale
# Processing Record 20 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 21 of Set 4 | vila franca do campo
# Processing Record 22 of Set 4 | aksum
# Processing Record 23 of Set 4 | coruripe
# Processing Record 24 of Set 4 | salalah
# Processing Record 25 of Set 4 | delemont
# Processing Record 26 of Set 4 | melfi
# Processing Record 27 of Set 4 | cockburn town
# Processing Record 28 of Set 4 | walvis bay
# Processing Record 29 of Set 4 | belyy yar
# Processing Record 30 of Set 4 | macas
# Processing Record 31 of Set 4 | ereymentau
# Processing Record 32 of Set 4 | ribeira grande
# Processing Record 33 of Set 4 | richards bay
# Processing Record 34 of Set 4 | laela
# Processing Record 35 of Set 4 | yirol
# City not found. Skipping...
# Processing Record 36 of Set 4 | borba
# Processing Record 37 of Set 4 | margate
# Processing Record 38 of Set 4 | araouane
# Processing Record 39 of Set 4 | rawson
# Processing Record 40 of Set 4 | spirovo
# Processing Record 41 of Set 4 | puerto montt
# Processing Record 42 of Set 4 | kuybysheve
# Processing Record 43 of Set 4 | hambantota
# Processing Record 44 of Set 4 | tiznit
# Processing Record 45 of Set 4 | inirida
# Processing Record 46 of Set 4 | sabha
# Processing Record 47 of Set 4 | mezen
# Processing Record 48 of Set 4 | catamarca
# Processing Record 49 of Set 4 | takoradi
# Processing Record 50 of Set 4 | ostrovnoy
# Processing Record 1 of Set 5 | skagen
# Processing Record 2 of Set 5 | castro
# Processing Record 3 of Set 5 | lamin
# Processing Record 4 of Set 5 | guder
# Processing Record 5 of Set 5 | grado
# Processing Record 6 of Set 5 | eenhana
# Processing Record 7 of Set 5 | marzuq
# Processing Record 8 of Set 5 | sorland
# Processing Record 9 of Set 5 | golspie
# Processing Record 10 of Set 5 | umm lajj
# Processing Record 11 of Set 5 | albany
# Processing Record 12 of Set 5 | kangaatsiaq
# Processing Record 13 of Set 5 | siret
# Processing Record 14 of Set 5 | tessalit
# Processing Record 15 of Set 5 | mizan teferi
# Processing Record 16 of Set 5 | saint-francois
# Processing Record 17 of Set 5 | sitrah
# Processing Record 18 of Set 5 | comodoro rivadavia
# Processing Record 19 of Set 5 | goderich
# Processing Record 20 of Set 5 | mitu
# Processing Record 21 of Set 5 | coquimbo
# Processing Record 22 of Set 5 | monrovia
# Processing Record 23 of Set 5 | high rock
# Processing Record 24 of Set 5 | maridi
# Processing Record 25 of Set 5 | olinda
# Processing Record 26 of Set 5 | namibe
# Processing Record 27 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 28 of Set 5 | saint augustine
# Processing Record 29 of Set 5 | gat
# Processing Record 30 of Set 5 | shymkent
# Processing Record 31 of Set 5 | grindavik
# Processing Record 32 of Set 5 | kedrovyy
# Processing Record 33 of Set 5 | ambato
# Processing Record 34 of Set 5 | san antonio
# Processing Record 35 of Set 5 | vardo
# Processing Record 36 of Set 5 | vite
# Processing Record 37 of Set 5 | ormara
# Processing Record 38 of Set 5 | sechura
# Processing Record 39 of Set 5 | nova olimpia
# Processing Record 40 of Set 5 | chibuto
# Processing Record 41 of Set 5 | moose factory
# Processing Record 42 of Set 5 | stornoway
# Processing Record 43 of Set 5 | halifax
# Processing Record 44 of Set 5 | agbor
# Processing Record 45 of Set 5 | tres arroyos
# Processing Record 46 of Set 5 | santa cruz
# Processing Record 47 of Set 5 | ussel
# Processing Record 48 of Set 5 | cap malheureux
# Processing Record 49 of Set 5 | aswan
# Processing Record 50 of Set 5 | axim
# Processing Record 1 of Set 6 | khanion tou kokkini
# City not found. Skipping...
# Processing Record 2 of Set 6 | omboue
# Processing Record 3 of Set 6 | henties bay
# Processing Record 4 of Set 6 | bafoulabe
# Processing Record 5 of Set 6 | sehithwa
# Processing Record 6 of Set 6 | suez
# Processing Record 7 of Set 6 | poroszlo
# Processing Record 8 of Set 6 | marevo
# Processing Record 9 of Set 6 | jacmel
# Processing Record 10 of Set 6 | kyzyl-suu
# Processing Record 11 of Set 6 | torbay
# Processing Record 12 of Set 6 | manakara
# Processing Record 13 of Set 6 | dingle
# Processing Record 14 of Set 6 | thinadhoo
# Processing Record 15 of Set 6 | warri
# Processing Record 16 of Set 6 | deder
# Processing Record 17 of Set 6 | grand-santi
# Processing Record 18 of Set 6 | olafsvik
# Processing Record 19 of Set 6 | murashi
# Processing Record 20 of Set 6 | turayf
# Processing Record 21 of Set 6 | paulo afonso
# Processing Record 22 of Set 6 | chama
# Processing Record 23 of Set 6 | boundiali
# Processing Record 24 of Set 6 | qaqortoq
# Processing Record 25 of Set 6 | dehri
# Processing Record 26 of Set 6 | sol-iletsk
# Processing Record 27 of Set 6 | alta floresta
# Processing Record 28 of Set 6 | state college
# Processing Record 29 of Set 6 | tawkar
# City not found. Skipping...
# Processing Record 30 of Set 6 | canakkale
# Processing Record 31 of Set 6 | kasempa
# Processing Record 32 of Set 6 | robertsport
# Processing Record 33 of Set 6 | najran
# Processing Record 34 of Set 6 | katima mulilo
# Processing Record 35 of Set 6 | banda aceh
# Processing Record 36 of Set 6 | lucea
# Processing Record 37 of Set 6 | ejea de los caballeros
# Processing Record 38 of Set 6 | betanzos
# Processing Record 39 of Set 6 | los llanos de aridane
# Processing Record 40 of Set 6 | atar
# Processing Record 41 of Set 6 | puri
# Processing Record 42 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 43 of Set 6 | santa cruz cabralia
# Processing Record 44 of Set 6 | tyukhtet
# Processing Record 45 of Set 6 | cascais
# Processing Record 46 of Set 6 | houma
# Processing Record 47 of Set 6 | sinnamary
# Processing Record 48 of Set 6 | antigonish
# Processing Record 49 of Set 6 | tuggurt
# City not found. Skipping...
# Processing Record 50 of Set 6 | huntsville
# Processing Record 1 of Set 7 | sliven
# Processing Record 2 of Set 7 | challapata
# Processing Record 3 of Set 7 | hobyo
# Processing Record 4 of Set 7 | trelew
# Processing Record 5 of Set 7 | wattegama
# Processing Record 6 of Set 7 | zonguldak
# Processing Record 7 of Set 7 | shar
# Processing Record 8 of Set 7 | mogadishu
# Processing Record 9 of Set 7 | abu samrah
# Processing Record 10 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 11 of Set 7 | sao raimundo nonato
# Processing Record 12 of Set 7 | krasnyy klyuch
# Processing Record 13 of Set 7 | maiduguri
# Processing Record 14 of Set 7 | praia da vitoria
# Processing Record 15 of Set 7 | copiapo
# Processing Record 16 of Set 7 | gardez
# Processing Record 17 of Set 7 | varkaus
# Processing Record 18 of Set 7 | royan
# Processing Record 19 of Set 7 | sudak
# Processing Record 20 of Set 7 | zhezkazgan
# Processing Record 21 of Set 7 | hedaru
# Processing Record 22 of Set 7 | khorixas
# Processing Record 23 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 7 | stephenville
# Processing Record 25 of Set 7 | kanturk
# Processing Record 26 of Set 7 | ongandjera
# Processing Record 27 of Set 7 | nizhniy baskunchak
# Processing Record 28 of Set 7 | roald
# Processing Record 29 of Set 7 | kocevje
# Processing Record 30 of Set 7 | kibondo
# Processing Record 31 of Set 7 | rio grande
# Processing Record 32 of Set 7 | beauceville
# Processing Record 33 of Set 7 | gobindpur
# Processing Record 34 of Set 7 | aleksandrovka
# Processing Record 35 of Set 7 | tuscaloosa
# Processing Record 36 of Set 7 | bonthe
# Processing Record 37 of Set 7 | polyarnyy
# Processing Record 38 of Set 7 | leh
# Processing Record 39 of Set 7 | ponta delgada
# Processing Record 40 of Set 7 | damietta
# Processing Record 41 of Set 7 | nioro
# Processing Record 42 of Set 7 | bilma
# Processing Record 43 of Set 7 | montbrison
# Processing Record 44 of Set 7 | bandarbeyla
# Processing Record 45 of Set 7 | san pedro de ycuamandiyu
# Processing Record 46 of Set 7 | chapais
# Processing Record 47 of Set 7 | abaza
# Processing Record 48 of Set 7 | urdzhar
# City not found. Skipping...
# Processing Record 49 of Set 7 | petrivka
# Processing Record 50 of Set 7 | staryy oskol
# Processing Record 1 of Set 8 | balykshi
# Processing Record 2 of Set 8 | danilovka
# Processing Record 3 of Set 8 | lapua
# Processing Record 4 of Set 8 | altamira
# Processing Record 5 of Set 8 | kulhudhuffushi
# Processing Record 6 of Set 8 | arlit
# Processing Record 7 of Set 8 | loukhi
# Processing Record 8 of Set 8 | tawnat
# City not found. Skipping...
# Processing Record 9 of Set 8 | turukhansk
# Processing Record 10 of Set 8 | witrivier
# City not found. Skipping...
# Processing Record 11 of Set 8 | iracoubo
# Processing Record 12 of Set 8 | bud
# Processing Record 13 of Set 8 | oussouye
# Processing Record 14 of Set 8 | kollo
# Processing Record 15 of Set 8 | mabaruma
# Processing Record 16 of Set 8 | garm
# City not found. Skipping...
# Processing Record 17 of Set 8 | veraval
# Processing Record 18 of Set 8 | dudinka
# Processing Record 19 of Set 8 | karacabey
# Processing Record 20 of Set 8 | kemijarvi
# Processing Record 21 of Set 8 | estelle
# Processing Record 22 of Set 8 | rovnoye
# Processing Record 23 of Set 8 | westport
# Processing Record 24 of Set 8 | sherbakul
# Processing Record 25 of Set 8 | talnakh
# Processing Record 26 of Set 8 | chingirlau
# Processing Record 27 of Set 8 | san cristobal
# Processing Record 28 of Set 8 | santa cruz del sur
# Processing Record 29 of Set 8 | yanam
# Processing Record 30 of Set 8 | skagastrond
# City not found. Skipping...
# Processing Record 31 of Set 8 | parchim
# Processing Record 32 of Set 8 | kabanga
# Processing Record 33 of Set 8 | bosaso
# Processing Record 34 of Set 8 | puerto maldonado
# Processing Record 35 of Set 8 | grootfontein
# Processing Record 36 of Set 8 | bayir
# Processing Record 37 of Set 8 | barkhan
# Processing Record 38 of Set 8 | zalesovo
# Processing Record 39 of Set 8 | luanda
# Processing Record 40 of Set 8 | buta
# Processing Record 41 of Set 8 | urengoy
# Processing Record 42 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 43 of Set 8 | diffa
# Processing Record 44 of Set 8 | zaplyusye
# City not found. Skipping...
# Processing Record 45 of Set 8 | sao jose da coroa grande
# Processing Record 46 of Set 8 | acarau
# Processing Record 47 of Set 8 | mvuma
# Processing Record 48 of Set 8 | sambava
# Processing Record 49 of Set 8 | la asuncion
# Processing Record 50 of Set 8 | sao joao da barra
# Processing Record 1 of Set 9 | balaghat
# Processing Record 2 of Set 9 | ales
# Processing Record 3 of Set 9 | wakefield
# Processing Record 4 of Set 9 | nizhyn
# Processing Record 5 of Set 9 | curillo
# Processing Record 6 of Set 9 | maltahohe
# Processing Record 7 of Set 9 | at-bashi
# Processing Record 8 of Set 9 | coihaique
# Processing Record 9 of Set 9 | beroroha
# Processing Record 10 of Set 9 | malindi
# Processing Record 11 of Set 9 | kondinskoye
# Processing Record 12 of Set 9 | petukhovo
# Processing Record 13 of Set 9 | trairi
# Processing Record 14 of Set 9 | tikhvin
# Processing Record 15 of Set 9 | sao felix do xingu
# Processing Record 16 of Set 9 | wagar
# Processing Record 17 of Set 9 | narsaq
# Processing Record 18 of Set 9 | harpalpur
# Processing Record 19 of Set 9 | pokaran
# Processing Record 20 of Set 9 | luderitz
# Processing Record 21 of Set 9 | chopda
# Processing Record 22 of Set 9 | krasnoselkup
# Processing Record 23 of Set 9 | acobamba
# Processing Record 24 of Set 9 | mahon
# Processing Record 25 of Set 9 | rauma
# Processing Record 26 of Set 9 | bjornevatn
# Processing Record 27 of Set 9 | mundwa
# Processing Record 28 of Set 9 | lere
# Processing Record 29 of Set 9 | necochea
# Processing Record 30 of Set 9 | ballina
# Processing Record 31 of Set 9 | chokwe
# Processing Record 32 of Set 9 | bonavista
# Processing Record 33 of Set 9 | horconcitos
# Processing Record 34 of Set 9 | adre
# Processing Record 35 of Set 9 | birjand
# Processing Record 36 of Set 9 | shenkursk
# Processing Record 37 of Set 9 | caravelas
# Processing Record 38 of Set 9 | ballsh
# Processing Record 39 of Set 9 | kara
# Processing Record 40 of Set 9 | kiruna
# Processing Record 41 of Set 9 | benicarlo
# Processing Record 42 of Set 9 | jiwani
# Processing Record 43 of Set 9 | quatre cocos
# Processing Record 44 of Set 9 | sile
# Processing Record 45 of Set 9 | tunduma
# Processing Record 46 of Set 9 | tacuati
# Processing Record 47 of Set 9 | waddan
# Processing Record 48 of Set 9 | bahar
# Processing Record 49 of Set 9 | kawardha
# Processing Record 50 of Set 9 | dharchula
# Processing Record 1 of Set 10 | inhambane
# Processing Record 2 of Set 10 | babaeski
# Processing Record 3 of Set 10 | kavaratti
# Processing Record 4 of Set 10 | mango
# Processing Record 5 of Set 10 | panaba
# Processing Record 6 of Set 10 | salekhard
# Processing Record 7 of Set 10 | hualmay
# Processing Record 8 of Set 10 | haveri
# Processing Record 9 of Set 10 | kasongo
# Processing Record 10 of Set 10 | verkhniy ufaley
# Processing Record 11 of Set 10 | bolshiye uki
# City not found. Skipping...
# Processing Record 12 of Set 10 | concordia
# Processing Record 13 of Set 10 | boende
# Processing Record 14 of Set 10 | mindelo
# Processing Record 15 of Set 10 | camabatela
# Processing Record 16 of Set 10 | concarneau
# Processing Record 17 of Set 10 | sabzevar
# Processing Record 18 of Set 10 | libertador general san martin
# Processing Record 19 of Set 10 | mahajanga
# Processing Record 20 of Set 10 | deogarh
# Processing Record 21 of Set 10 | sao filipe
# Processing Record 22 of Set 10 | baghdad
# Processing Record 23 of Set 10 | sergeyevka
# Processing Record 24 of Set 10 | florianopolis
# Processing Record 25 of Set 10 | santiago del estero
# Processing Record 26 of Set 10 | sistranda
# Processing Record 27 of Set 10 | mungaa
# Processing Record 28 of Set 10 | chebenki
# Processing Record 29 of Set 10 | sisimiut
# Processing Record 30 of Set 10 | lozovik
# Processing Record 31 of Set 10 | lunenburg
# Processing Record 32 of Set 10 | braganca paulista
# Processing Record 33 of Set 10 | kuybyshevo
# Processing Record 34 of Set 10 | columbus
# Processing Record 35 of Set 10 | ubatuba
# Processing Record 36 of Set 10 | bartica
# Processing Record 37 of Set 10 | lerwick
# Processing Record 38 of Set 10 | derazhnya
# Processing Record 39 of Set 10 | charlestown
# Processing Record 40 of Set 10 | galle
# Processing Record 41 of Set 10 | totness
# Processing Record 42 of Set 10 | mouzakion
# City not found. Skipping...
# Processing Record 43 of Set 10 | warrington
# Processing Record 44 of Set 10 | taoudenni
# Processing Record 45 of Set 10 | chicama
# Processing Record 46 of Set 10 | altay
# Processing Record 47 of Set 10 | nizwa
# Processing Record 48 of Set 10 | sredniy ikorets
# Processing Record 49 of Set 10 | kumbo
# Processing Record 50 of Set 10 | la plata
# Processing Record 1 of Set 11 | nagod
# Processing Record 2 of Set 11 | karauzyak
# City not found. Skipping...
# Processing Record 3 of Set 11 | acoyapa
# Processing Record 4 of Set 11 | asfi
# Processing Record 5 of Set 11 | riyadh
# Processing Record 6 of Set 11 | giyon
# Processing Record 7 of Set 11 | birao
# Processing Record 8 of Set 11 | nieuw amsterdam
# Processing Record 9 of Set 11 | requena
# Processing Record 10 of Set 11 | blonduos
# City not found. Skipping...
# Processing Record 11 of Set 11 | rolim de moura
# City not found. Skipping...
# Processing Record 12 of Set 11 | santa maria
# Processing Record 13 of Set 11 | la palma
# Processing Record 14 of Set 11 | gursarai
# Processing Record 15 of Set 11 | point fortin
# Processing Record 16 of Set 11 | abu dhabi
# Processing Record 17 of Set 11 | marhaura
# Processing Record 18 of Set 11 | tahta
# Processing Record 19 of Set 11 | ljungby
# Processing Record 20 of Set 11 | krasnyy luch
# Processing Record 21 of Set 11 | kargasok
# Processing Record 22 of Set 11 | lahij
# Processing Record 23 of Set 11 | fort wellington
# Processing Record 24 of Set 11 | sadiqabad
# Processing Record 25 of Set 11 | solovetskiy
# City not found. Skipping...
# Processing Record 26 of Set 11 | meybod
# Processing Record 27 of Set 11 | lagos
# Processing Record 28 of Set 11 | barcelona
# Processing Record 29 of Set 11 | pavda
# City not found. Skipping...
# Processing Record 30 of Set 11 | deer lake
# Processing Record 31 of Set 11 | porto novo
# Processing Record 32 of Set 11 | derby
# Processing Record 33 of Set 11 | aguimes
# Processing Record 34 of Set 11 | pangody
# Processing Record 35 of Set 11 | abu jubayhah
# City not found. Skipping...
# Processing Record 36 of Set 11 | tazovskiy
# Processing Record 37 of Set 11 | safwah
# City not found. Skipping...
# Processing Record 38 of Set 11 | lanester
# Processing Record 39 of Set 11 | asyut
# Processing Record 40 of Set 11 | maragogi
# Processing Record 41 of Set 11 | ancud
# Processing Record 42 of Set 11 | barcelos
# Processing Record 43 of Set 11 | guadalajara
# Processing Record 44 of Set 11 | saint-georges
# Processing Record 45 of Set 11 | baldeogarh
# Processing Record 46 of Set 11 | grand gaube
# Processing Record 47 of Set 11 | tonstad
# Processing Record 48 of Set 11 | nicoya
# Processing Record 49 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 50 of Set 11 | kollumerland
# City not found. Skipping...
# Processing Record 1 of Set 12 | pelym
# Processing Record 2 of Set 12 | pryazha
# Processing Record 3 of Set 12 | bizhbulyak
# Processing Record 4 of Set 12 | asosa
# Processing Record 5 of Set 12 | waw
# Processing Record 6 of Set 12 | gangotri
# City not found. Skipping...
# Processing Record 7 of Set 12 | hofn
# Processing Record 8 of Set 12 | viransehir
# Processing Record 9 of Set 12 | praia
# Processing Record 10 of Set 12 | mosquera
# Processing Record 11 of Set 12 | karasjok
# Processing Record 12 of Set 12 | albanel
# Processing Record 13 of Set 12 | edgewater
# Processing Record 14 of Set 12 | marawi
# Processing Record 15 of Set 12 | hamilton
# Processing Record 16 of Set 12 | angra
# City not found. Skipping...
# Processing Record 17 of Set 12 | hopkinsville
# Processing Record 18 of Set 12 | pudozh
# Processing Record 19 of Set 12 | buraydah
# Processing Record 20 of Set 12 | shache
# Processing Record 21 of Set 12 | safut
# Processing Record 22 of Set 12 | raahe
# Processing Record 23 of Set 12 | whitehaven
# Processing Record 24 of Set 12 | lerik
# Processing Record 25 of Set 12 | gweta
# Processing Record 26 of Set 12 | sainte-anne-des-monts
# Processing Record 27 of Set 12 | samana
# Processing Record 28 of Set 12 | shcherbinka
# Processing Record 29 of Set 12 | angelholm
# City not found. Skipping...
# Processing Record 30 of Set 12 | aripuana
# Processing Record 31 of Set 12 | aquidaba
# Processing Record 32 of Set 12 | nadvoitsy
# Processing Record 33 of Set 12 | verkhnyaya inta
# Processing Record 34 of Set 12 | oranjemund
# Processing Record 35 of Set 12 | abrau-dyurso
# Processing Record 36 of Set 12 | lesnoy
# Processing Record 37 of Set 12 | odweyne
# Processing Record 38 of Set 12 | ankpa
# Processing Record 39 of Set 12 | shakawe
# Processing Record 40 of Set 12 | usinsk
# Processing Record 41 of Set 12 | kirzhach
# Processing Record 42 of Set 12 | havelock
# Processing Record 43 of Set 12 | vredendal
# Processing Record 44 of Set 12 | lewisporte
# Processing Record 45 of Set 12 | oistins
# Processing Record 46 of Set 12 | portree
# Processing Record 47 of Set 12 | saint-pierre
# Processing Record 48 of Set 12 | portoferraio
# Processing Record 49 of Set 12 | brokopondo
# Processing Record 50 of Set 12 | malakal
# Processing Record 1 of Set 13 | zabol
# Processing Record 2 of Set 13 | kalakamati
# Processing Record 3 of Set 13 | haapsalu
# Processing Record 4 of Set 13 | demba
# Processing Record 5 of Set 13 | kontagora
# Processing Record 6 of Set 13 | porbandar
# Processing Record 7 of Set 13 | semnan
# Processing Record 8 of Set 13 | itamarandiba
# Processing Record 9 of Set 13 | dakar
# Processing Record 10 of Set 13 | andenes
# Processing Record 11 of Set 13 | kars
# Processing Record 12 of Set 13 | koungou
# Processing Record 13 of Set 13 | muyezerskiy
# Processing Record 14 of Set 13 | ilhabela
# Processing Record 15 of Set 13 | mallama
# City not found. Skipping...
# Processing Record 16 of Set 13 | nantucket
# Processing Record 17 of Set 13 | oskarshamn
# Processing Record 18 of Set 13 | romanovo
# Processing Record 19 of Set 13 | karaton
# Processing Record 20 of Set 13 | kudahuvadhoo
# Processing Record 21 of Set 13 | carnarvon
# Processing Record 22 of Set 13 | bantry
# Processing Record 23 of Set 13 | babanusah
# City not found. Skipping...
# Processing Record 24 of Set 13 | roberto payan
# City not found. Skipping...
# Processing Record 25 of Set 13 | presidencia roque saenz pena
# Processing Record 26 of Set 13 | kumluca
# Processing Record 27 of Set 13 | mapiripan
# Processing Record 28 of Set 13 | kyshtovka
# Processing Record 29 of Set 13 | matadi
# Processing Record 30 of Set 13 | faya
# Processing Record 31 of Set 13 | imbituba
# Processing Record 32 of Set 13 | puerto ayora
# Processing Record 33 of Set 13 | igrim
# Processing Record 34 of Set 13 | escanaba
# Processing Record 35 of Set 13 | derzhavinsk
# Processing Record 36 of Set 13 | poshekhonye
# Processing Record 37 of Set 13 | ugoofaaru
# Processing Record 38 of Set 13 | utica
# Processing Record 39 of Set 13 | paamiut
# Processing Record 40 of Set 13 | mizdah
# Processing Record 41 of Set 13 | sao domingos
# Processing Record 42 of Set 13 | anzio
# Processing Record 43 of Set 13 | thompson
# Processing Record 44 of Set 13 | naryan-mar
# Processing Record 45 of Set 13 | camacha
# Processing Record 46 of Set 13 | visnes
# Processing Record 47 of Set 13 | tucuma
# Processing Record 48 of Set 13 | urambo
# Processing Record 49 of Set 13 | dubrovnik
# Processing Record 50 of Set 13 | kamenka
# Processing Record 1 of Set 14 | uzunovo
# Processing Record 2 of Set 14 | buchanan
# Processing Record 3 of Set 14 | pozo colorado
# Processing Record 4 of Set 14 | yarada
# Processing Record 5 of Set 14 | senaki
# Processing Record 6 of Set 14 | takaungu
# Processing Record 7 of Set 14 | aranyosapati
# Processing Record 8 of Set 14 | bolgatanga
# Processing Record 9 of Set 14 | mercedes
# Processing Record 10 of Set 14 | lodja
# Processing Record 11 of Set 14 | mariental
# Processing Record 12 of Set 14 | soderhamn
# Processing Record 13 of Set 14 | villa carlos paz
# Processing Record 14 of Set 14 | almeirim
# Processing Record 15 of Set 14 | awjilah
# Processing Record 16 of Set 14 | zambezi
# Processing Record 17 of Set 14 | awbari
# Processing Record 18 of Set 14 | mutis
# Processing Record 19 of Set 14 | nosy varika
# Processing Record 20 of Set 14 | kinkala
# Processing Record 21 of Set 14 | trebinje
# Processing Record 22 of Set 14 | tukrah
# Processing Record 23 of Set 14 | filingue
# Processing Record 24 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 25 of Set 14 | saint monans
# Processing Record 26 of Set 14 | groningen
# Processing Record 27 of Set 14 | matay
# Processing Record 28 of Set 14 | podstepki
# Processing Record 29 of Set 14 | talcahuano
# Processing Record 30 of Set 14 | lakeside
# Processing Record 31 of Set 14 | borlange
# City not found. Skipping...
# Processing Record 32 of Set 14 | yangambi
# Processing Record 33 of Set 14 | kharp
# Processing Record 34 of Set 14 | eucaliptus
# Processing Record 35 of Set 14 | uvat
# Processing Record 36 of Set 14 | gusau
# Processing Record 37 of Set 14 | sinkat
# City not found. Skipping...
# Processing Record 38 of Set 14 | barabinsk
# Processing Record 39 of Set 14 | vozhega
# Processing Record 40 of Set 14 | bolintin deal
# Processing Record 41 of Set 14 | marsh harbour
# Processing Record 42 of Set 14 | uarini
# Processing Record 43 of Set 14 | satipo
# Processing Record 44 of Set 14 | san andres
# Processing Record 45 of Set 14 | fomboni
# Processing Record 46 of Set 14 | arica
# Processing Record 47 of Set 14 | honningsvag
# Processing Record 48 of Set 14 | samarkand
# Processing Record 49 of Set 14 | kushmurun
# Processing Record 50 of Set 14 | larsnes
# Processing Record 1 of Set 15 | san carlos de bariloche
# Processing Record 2 of Set 15 | teya
# Processing Record 3 of Set 15 | geraldton
# Processing Record 4 of Set 15 | paita
# Processing Record 5 of Set 15 | kismayo
# Processing Record 6 of Set 15 | ambodifototra
# City not found. Skipping...
# Processing Record 7 of Set 15 | pangoa
# Processing Record 8 of Set 15 | kutahya
# Processing Record 9 of Set 15 | ust-koksa
# Processing Record 10 of Set 15 | leshukonskoye
# Processing Record 11 of Set 15 | kyabe
# Processing Record 12 of Set 15 | san rafael abajo
# Processing Record 13 of Set 15 | bay roberts
# Processing Record 14 of Set 15 | destin
# Processing Record 15 of Set 15 | sholapur
# Processing Record 16 of Set 15 | chistogorskiy
# Processing Record 17 of Set 15 | dinsor
# City not found. Skipping...
# Processing Record 18 of Set 15 | surt
# Processing Record 19 of Set 15 | arona
# Processing Record 20 of Set 15 | sidi ali
# Processing Record 21 of Set 15 | benjamin constant
# Processing Record 22 of Set 15 | turuvekere
# Processing Record 23 of Set 15 | staromaryevka
# City not found. Skipping...
# Processing Record 24 of Set 15 | leua
# Processing Record 25 of Set 15 | puerto baquerizo moreno
# Processing Record 26 of Set 15 | ostersund
# Processing Record 27 of Set 15 | neringa
# Processing Record 28 of Set 15 | tabulbah
# City not found. Skipping...
# Processing Record 29 of Set 15 | sarkand
# Processing Record 30 of Set 15 | hilton head island
# Processing Record 31 of Set 15 | aranos
# Processing Record 32 of Set 15 | rio gallegos
# Processing Record 33 of Set 15 | nara
# Processing Record 34 of Set 15 | lethem
# Processing Record 35 of Set 15 | nyuksenitsa
# Processing Record 36 of Set 15 | havre-saint-pierre
# Processing Record 37 of Set 15 | sokoni
# Processing Record 38 of Set 15 | roros
# Processing Record 39 of Set 15 | vytegra
# Processing Record 40 of Set 15 | stupino
# Processing Record 41 of Set 15 | englehart
# Processing Record 42 of Set 15 | terme
# Processing Record 43 of Set 15 | sosnogorsk
# Processing Record 44 of Set 15 | aix-en-provence
# Processing Record 45 of Set 15 | teonthar
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Add the data to a new DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                        City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0                    Dikson  73.5069  80.5464    259.39        94         100
# 1               Porto Velho  -8.7619 -63.9039    300.18        83          75
# 2            Cap-Aux-Meules  47.3821 -61.8597    278.18        60          20
# 3  Channel-Port Aux Basques  47.5702 -59.1367    274.74        71           8
# 4                   Itarema  -2.9248 -39.9167    302.39        70          32
# 5                    Kikwit  -5.0410  18.8162    303.70        54          69
# 6                     Kayes  14.0000 -11.0000    313.48         8           6
# 7                 Hithadhoo  -0.6000  73.0833    302.40        65           9
# 8              Vangaindrano -23.3500  47.6000    296.96        90         100
# 9                      Nuuk  64.1835 -51.7216    276.49        75         100
#
#    Wind Speed Country Current Description                 Date
# 0        6.63      RU     overcast clouds  2022-04-21 14:25:27
# 1        2.06      BR       broken clouds  2022-04-21 14:25:27
# 2        5.66      CA          few clouds  2022-04-21 14:25:28
# 3       10.27      CA           clear sky  2022-04-21 14:24:09
# 4        5.52      BR    scattered clouds  2022-04-21 14:25:28
# 5        0.68      CD       broken clouds  2022-04-21 14:25:29
# 6        2.02      ML           clear sky  2022-04-21 14:25:29
# 7        3.23      MV           clear sky  2022-04-21 14:25:29
# 8        3.65      MG       moderate rain  2022-04-21 14:25:30
# 9       14.40      GL     overcast clouds  2022-04-21 14:23:20

# %%
# Reorder the columns in the DataFrame
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

#Assign data frame the new column order
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#                          City Country      Lat      Lng  Max Temp  Humidity  \
# 0                      Dikson      RU  73.5069  80.5464    259.39        94
# 1                 Porto Velho      BR  -8.7619 -63.9039    300.18        83
# 2              Cap-Aux-Meules      CA  47.3821 -61.8597    278.18        60
# 3    Channel-Port Aux Basques      CA  47.5702 -59.1367    274.74        71
# 4                     Itarema      BR  -2.9248 -39.9167    302.39        70
# ..                        ...     ...      ...      ...       ...       ...
# 678                 Englehart      CA  47.8169 -79.8664    275.16       100
# 679                     Terme      TR  41.2092  36.9739    284.11        80
# 680                Sosnogorsk      RU  63.6023  53.8817    270.91        69
# 681           Aix-En-Provence      FR  43.5283   5.4497    290.95        70
# 682                  Teonthar      IN  24.9833  81.6500    309.46        14
#
#      Cloudiness  Wind Speed Current Description
# 0           100        6.63     overcast clouds
# 1            75        2.06       broken clouds
# 2            20        5.66          few clouds
# 3             8       10.27           clear sky
# 4            32        5.52    scattered clouds
# ..          ...         ...                 ...
# 678         100        7.20          light snow
# 679          77        2.14       broken clouds
# 680          97        2.88     overcast clouds
# 681         100        1.97          light rain
# 682          31        1.99    scattered clouds
#
# [683 rows x 9 columns]

# %%
#Export the DataFrame as a CSV file
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Deliberable 1 End
